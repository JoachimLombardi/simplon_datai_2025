# %% [markdown]
# 1. Tracer un graphe linéaire des points (x, y) où x = [0, 1, 2, 3, 4] et y = [1, 4, 3, 8, 5].

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0, 1, 2, 3, 4]
y = [1, 4, 3, 8, 5]
plt.plot(x, y)

# %% [markdown]
# Tracer un histogramme à partir de données aléatoires générées par NumPy.

# %%
alea = np.random.randn(50)
alea
# Out:
# array([-0.88516708, -1.07040432, -1.13771604,  1.1150076 ,  0.31337316,
#         0.45306618,  1.29802588, -1.9835534 , -0.43228986, -0.3771854 ,
#         1.34052372, -0.02643623,  0.7118159 ,  0.4958416 , -1.53188616,
#         1.17161718, -0.82416032,  0.49701625, -0.60963841,  0.73813318,
#         0.80589616,  1.1983919 ,  0.17704309, -0.49652648, -1.06112616,
#        -0.73503068,  0.8083973 , -0.60559279,  1.71319976, -1.70011383,
#        -1.40058948, -1.76416482,  0.00792307, -0.38287671, -1.37612437,
#         0.58586794, -1.004831  ,  1.28911222,  0.28833649, -1.01922881,
#        -0.65513636,  0.00809375,  0.58934174,  0.57788663,  0.30222139,
#         0.35151544,  0.64500151, -0.51183893,  1.93722481, -0.18221401])

# %%
plt.hist(alea, bins=10, density=True, color="red", edgecolor = "white", linewidth=5)
# Out:
# (array([0.15303084, 0.15303084, 0.35707197, 0.35707197, 0.20404113,
#         0.35707197, 0.45909253, 0.15303084, 0.25505141, 0.10202056]),
#  array([-1.9835534 , -1.59147558, -1.19939776, -0.80731994, -0.41524212,
#         -0.0231643 ,  0.36891353,  0.76099135,  1.15306917,  1.54514699,
#          1.93722481]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Tracer un diagramme à barres à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D', 'E'], valeurs = [25, 30, 15, 20, 10]

# %%
categories = ['A', 'B', 'C', 'D', 'E']
valeurs = [25, 30, 15, 20, 10]

# %%
plt.bar(categories, valeurs, 0.8)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Tracer un nuage de points à partir de données aléatoires générées par NumPy.

# %%
nuage = np.random.randn(5000)

# %%
plt.plot(nuage, "-->")

# %% [markdown]
# Tracer une courbe sinusoïdale en utilisant NumPy.

# %%
x = np.arange(-20, 20)
sinus = np.sin(x)

# %%
plt.plot(x, sinus)

# %% [markdown]
# Tracer deux courbes sur le même graphe à partir des données suivantes :
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# Tracer un diagramme en secteurs (camembert) à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D'], valeurs = [30, 25, 15, 20]

# %%
categories = ['A', 'B', 'C', 'D']
valeurs = [30, 25, 15, 20]

# %%
plt.pie(valeurs, 
        labels=categories, 
        explode = [0, 0.3, 0, 0], 
        colors=["gold", "yellow", "purple", "indigo"],
        shadow=True,
        labeldistance=0.8,
        autopct = lambda x: str(round(x, 2)) + '%',
        pctdistance = 0.4);

# %% [markdown]
# Tracer une courbe polynomiale à partir des données suivantes :
# x = np.linspace(-5, 5, 100)
# y = 3 * x**3 + 2 * x**2 - 8 * x + 5

# %%
x = np.linspace(-5, 5, 100)
y = 3 * x**3 + 2 * x**2 - 8 * x + 5

# %%
plt.plot(x, y)

# %% [markdown]
# Tracer un diagramme en barres empilées à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D']
# valeurs1 = [10, 15, 20, 25], valeurs2 = [5, 10, 15, 20]

# %%
categories = ['A', 'B', 'C', 'D']
valeurs1 = [10, 15, 20, 25]
valeurs2 = [5, 10, 15, 20]

# %%
plt.bar(categories, valeurs1, label="valeurs1")
plt.bar(categories, valeurs2, label="valeurs2")
plt.legend()

# %% [markdown]
# Tracer un graphique en boîte (boxplot) à partir des données suivantes :
# data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

# %%
data = [np.random.normal(0, 1, 100),
np.random.normal(2, 1, 100),
np.random.normal(-8, 8, 10)]
plt.boxplot(data);
